# %%
from MLP import *

# %%
d = Dense(10, activation='relu')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 d = Dense(10, activation='relu')
#
# TypeError: Dense.__init__() got an unexpected keyword argument 'activation'

# %%
output = d.foward([1, 2, 3])
# Out:
# Weight: [0.5690006383654762, -0.7765582045644943, 0.8473594133473197, 0.7228917347203283]
# Weight: [0.5692722668108163, 0.02517525280424171, 0.5034342961018694, -0.06441669052138388]
# Weight: [-0.8184731743563483, -0.884650860320686, -0.8493971838435674, 0.1396891808763432]
# Weight: [-0.3585950632976369, -0.10632940290202253, -0.9100324562970279, 0.8349743620947201]
# Weight: [-0.07807577374028885, -0.6910310016456205, -0.31575994003145524, -0.7190171865795081]
# Weight: [0.8776927649400408, -0.9405496386979657, 0.3334568937825211, 0.8558414308888362]
# Weight: [-0.8288265485814834, 0.840832664293991, 0.9094993145125985, -0.842432713657751]
# Weight: [-0.23208268197852244, -0.5008093789202941, 0.2892322727041259, 0.6087627054895284]
# Weight: [-0.9696708786317143, -0.9413825545467056, -0.3217901189563961, -0.4509570573553894]
# Weight: [-0.6101146365920738, -0.7147120906274238, -0.34210312797803755, 0.24785006683400934]
# x :     [1, 1, 2, 3]
# ...

# %%
output
# Out:
# [3.6558364646566064,
#  1.4080660402546452,
#  2.982850859735139,
#  0.21993370749044505,
#  3.5576782151873436,
#  3.1715812064736255,
#  0.6962933962355482,
#  1.6718606009780204,
#  3.90750484315738,
#  1.2654827826735444]
